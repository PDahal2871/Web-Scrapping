# %%
from PyDictionary import PyDictionary

dictionary=PyDictionary()

# %%
from bs4 import BeautifulSoup #for scraping
import requests               #required for reading the file
from selenium import webdriver 
import pandas as pd 
from selenium.webdriver.support.ui import WebDriverWait

# %%
import warnings
import time
warnings.filterwarnings("ignore")
options = webdriver.ChromeOptions()
options.add_argument("headless") #to stop opening new chrome browser on every hit
driver=webdriver.Chrome('D:\chromedriver.exe', chrome_options=options)

# %%
import json
from bs4 import BeautifulSoup

# %%
print("ID:",ID)
print()
print("Title:",title)
print()
print("Description:",description)
print()
print("Channel ID:",channel_id)
print()
print("Published at:",publishedAt)
print()
print("Thumbnail URL:",thumbnailUrl)
print()
print("Channel Title:",channelTitle)
print()
print("Tags:",tags)
print()
print("Category ID:",categoryId)
print()
print("View Count:", viewCount)
print()
print("Like Count:", likeCount)
print()
print("Dislike Count:",dislikeCount)
print()
print("Favorite Count:",favoriteCount)
print()
print("Comment Count:",commentCount)
print()
print("Upload Status:", uploadStatus)
print()
print("Privacy Status:",privacyStatus)
print()
print("License:", license)
print()
print("Embeddable:",embededdable)
print()
print("Public Stats Viewable:",publicStatsViewable)
print()
# Out:
# ID: DEthQBth310
#
# Title: Cristiano Ronaldo can't Stop Scoring!
#
# Description: 📲 SUBSCRIBE AND TURN ON YOUR ON YOUR NOTIFICATIONS!
#
#
# Behance: https://www.behance.net/al7nd
# Donate if you want: https://www.paypal.me/Ndoi
#
# This content is both in Transformative and Educational nature.
# Video is in compliance with Content Quality section of YPP Policies as the editing adds creative value which makes the content unique.
#
# ----------------------------------------­--------------------------
# © Alsido Football
#
# Channel ID: UC9j-24zF2RK7obcSPrSd7Lg
#
# Published at: 2020-09-27T22:32:07Z
#
# Thumbnail URL: https://i.ytimg.com/vi/DEthQBth310/default.jpg
#
# Channel Title: Alsido Football
#
# Tags: ['Not found']
#
# Category ID: 17
#
# View Count: <class 'str'>
#
# Like Count: <class 'str'>
#
# Dislike Count: <class 'str'>
#
# Favorite Count: <class 'str'>
#
# Comment Count: <class 'str'>
#
# Upload Status: processed
#
# Privacy Status: public
#
# License: youtube
#
# Embeddable: True
#
# Public Stats Viewable: True

# %% [markdown]
# ## Main code starts here

# %%
from PyDictionary import PyDictionary

dictionary=PyDictionary()

# %%
from bs4 import BeautifulSoup #for scraping
import requests               #required for reading the file
from selenium import webdriver 
import pandas as pd 
from selenium.webdriver.support.ui import WebDriverWait

# %%
import warnings
import time, random
warnings.filterwarnings("ignore")
options = webdriver.ChromeOptions()
options.add_argument("headless") #to stop opening new chrome browser on every hit
driver=webdriver.Chrome('D:\chromedriver.exe', chrome_options=options) #change path location to your path

# %%
from selenium.webdriver.common.keys import Keys
import json, pickle
from textblob import TextBlob
from textblob import Word
import mysql.connector as db
import numpy as np

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException

# %%
# options = webdriver.ChromeOptions()
# options.add_argument("start-maximized")
# options.add_argument("headless") #to stop opening new chrome browser on every hit
# options.add_experimental_option("excludeSwitches", ["enable-automation"])
# options.add_experimental_option('useAutomationExtension', False)
# driver = webdriver.Chrome(chrome_options=options, executable_path=r'D:\chromedriver.exe')
# driver.get("https://sslproxies.org/")
# driver.execute_script("return arguments[0].scrollIntoView(true);", WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table[@class='table table-striped table-bordered dataTable']//th[contains(., 'IP Address')]"))))
# ips = [my_elem.get_attribute("innerHTML") for my_elem in WebDriverWait(driver, 5).until(EC.visibility_of_all_elements_located((By.XPATH, "//table[@class='table table-striped table-bordered dataTable']//tbody//tr[@role='row']/td[position() = 1]")))]
# ports = [my_elem.get_attribute("innerHTML") for my_elem in WebDriverWait(driver, 5).until(EC.visibility_of_all_elements_located((By.XPATH, "//table[@class='table table-striped table-bordered dataTable']//tbody//tr[@role='row']/td[position() = 2]")))]
# driver.quit()
# proxies = []
# for i in range(0, len(ips)):
#     proxies.append(ips[i]+':'+ports[i])

# %%
mydb = db.connect(host="video-scrapping-db.cnmkmpcubdot.us-east-2.rds.amazonaws.com",
  user="asmi",
  password="asmipass123")

mycursor = mydb.cursor()
try:
    mycursor.execute("CREATE DATABASE YOUTUBE")
except:
    pass

# %%
# Create table as per requirement
sql = """CREATE TABLE IF NOT EXISTS nissan_car (
    id INT(80) primary key NOT NULL AUTO_INCREMENT,
    object_name VARCHAR(100),
    timestamp VARCHAR(100),
    video_ID VARCHAR(80),
    link VARCHAR(100),
    title VARCHAR(200),
    description VARCHAR(200),
    channel_id VARCHAR(100),
    publishedAt VARCHAR(100),
    thumbnailUrl VARCHAR(100),
    channelTitle VARCHAR(200),
    tags VARCHAR(100),
    categoryId VARCHAR(100),
    viewCount VARCHAR(100),
    likeCount VARCHAR(100),
    dislikeCount VARCHAR(100),
    favoriteCount VARCHAR(100),
    commentCount VARCHAR(100),
    uploadStatus VARCHAR(70),
    privacyStatus VARCHAR(100),
    license VARCHAR(100),
    embeddable VARCHAR(100),
    publicStatsviewable VARCHAR(100)
    )"""

# Create table as per requirement
conn = db.connect(host="video-scrapping-db.cnmkmpcubdot.us-east-2.rds.amazonaws.com",
  user="asmi",
  password="asmipass123", database='METADATA')
cur = conn.cursor()
cur.execute(sql)
cur.close()
conn.commit()
conn.close()
# Out:
# ---------------------------------------------------------------------------
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-34-6ad87ab35e67> in <module>
#      32   password="asmipass123", database='METADATA')
#      33 cur = conn.cursor()
# ---> 34 cur.execute(sql1)
#      35 cur.close()
#      36 conn.commit()
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\cursor.py in execute(self, operation, params, multi)
#     567
#     568         try:
# --> 569             self._handle_result(self._connection.cmd_query(stmt))
#     570         except errors.InterfaceError:
#     571             if self._connection._have_next_result:  # pylint: disable=W0212
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\connection.py in cmd_query(self, query, raw, buffered, raw_as_string)
#     597         if not isinstance(query, bytes):
#     598             query = query.encode('utf-8')
# --> 599         result = self._handle_result(self._send_cmd(ServerCmd.QUERY, query))
#     600
#     601         if self._have_next_result:
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\connection.py in _handle_result(self, packet)
#     485             return self._handle_eof(packet)
#     486         elif packet[4] == 255:
# --> 487             raise errors.get_exception(packet)
#     488
#     489         # We have a text result set
#
# DatabaseError: 1093 (HY000): You can't specify target table 'nissan_car' for update in FROM clause

# %%
all_links = []
links = []
ID = []
title = []
description = []
channel_id = []
publishedAt = []
thumbnailUrl = []
channelTitle = []
tags = []
categoryId = []
viewCount = []
likeCount = []
dislikeCount = []
favoriteCount = []
commentCount = []
uploadStatus = []
privacyStatus = []
license = []
embededdable = []
publicStatsViewable = []
i_key = 0 
#unique_ids = pickle.load(open('unique_ids.pickle', 'rb'))
#df = pd.read_csv('df.csv')
unique_ids_nissan = set()

df_nissan = pd.DataFrame(columns = ['object_name','timestamp','video_ID', 'link', 'title', 'description', 'channel_id', 'publishedAt', 'thumbnailUrl', 'channelTitle', 'tags', 'categoryId', 'viewCount', 'likeCount', 'dislikeCount', 'favoriteCount', 'commentCount', 'uploadStatus', 'privacyStatus', 'license', 'embeddable', 'publicStatsviewable'])

# %%
df_nissan.shape
# Out:
# (0, 22)

# %%
def get_scrapper(ids, query):
    print(query)
    print(ids)
    global i_key
    categories = ['snippet', 'statistics', 'status']
    keys = [
        'AIzaSyDhUDId1C0UGN86bUozDS-sRQQ1pHfmtaE',
        'AIzaSyAoea6ypnSVa0hYvCjhkyjz5KXs1HKyp8I',
        'AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk',
        'AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU',
        'AIzaSyBx_uTQjDduZw9TNdDQsXkizEyC95oLeEE',
        'AIzaSyABTa7kmK3tfrbMOKeOvetOXyJ7t7tqzFw',
        'AIzaSyAl2RFyRYZK0J0ZNF0DnWlP5OuN8RhjE0g'
    ]
    print(keys[i_key])
    for cat in categories:
        driver.get("https://www.googleapis.com/youtube/v3/videos?part=" + cat + "&id=" + ids + "&key="+ keys[i_key])
       
        soup = BeautifulSoup(driver.page_source, 'html.parser')
        user_data = soup.find('pre').contents[0]
        user_data = user_data.replace('\n','')

        user_data = json.loads(user_data)
        
        if user_data.get('items'):
            items = user_data['items'][0]
            if cat == 'snippet':
                #for snippet
                local_ID = items['id']
                local_title = items['snippet']['title']
                local_description = items.get('snippet').get('description', "Not Found")
                local_channel_id = items['snippet']['channelId']
                local_publishedAt = items['snippet']['publishedAt']
                local_thumbnailUrl = items['snippet']['thumbnails']['default']['url']
                local_channelTitle = items['snippet']['channelTitle']
                local_tag = items.get('snippet').get('tags',["Not found"])
                local_tags = ','.join(local_tag)
                local_categoryId = items['snippet']['categoryId']

            elif cat == 'statistics':
                #for statistics
                local_Count = items.get('statistics').get('viewCount',0) 
                local_likeCount = items.get('statistics').get('likeCount',0) 
                local_dislikeCount = items.get('statistics').get('dislikeCount',0)
                local_favoriteCount = items.get('statistics').get('favoriteCount',0)
                local_commentCount = items.get('statistics').get('commentCount',0) 

            else:
                #for status
                local_uploadStatus = items['status']['uploadStatus']
                local_privacyStatus = items['status']['privacyStatus']
                local_license = items['status']['license']
                local_embededdable = items['status']['embeddable']
                local_publicStatsViewable = items['status']['publicStatsViewable']
                
        else:
            i_key+=1
            if i_key>=len(keys):
                return "All API key visited for today"
            return
            
        
    total_data = [local_ID, local_title, local_description, local_channel_id, local_publishedAt, local_thumbnailUrl, 
                  local_channelTitle, local_tags, local_categoryId, 
                  local_Count, local_likeCount, local_dislikeCount, local_favoriteCount, 
                  local_commentCount, local_uploadStatus, local_privacyStatus,
                  local_license, local_embededdable, local_publicStatsViewable
                 ]
    return total_data

# %%
from selenium.webdriver.common.keys import Keys

def scrapper(t, query):

    driver.get(f"https://www.youtube.com/results?search_query={query}")
    
    for i in range(1,400):  #Scroll 400 times
        html = driver.find_element_by_tag_name('html')
        html.send_keys(Keys.END)

    user_data = driver.find_elements_by_xpath('//*[@id="video-title"]')

    for i1 in user_data:
        links.append(i1.get_attribute('href'))
    
    new_links = [link for link in set(links) if link is not None]
    IDs = [link.split('=')[1] for link in set(links) if link is not None]
    
    for i, link in zip(IDs, new_links):
        global unique_ids_nissan
        if i in unique_ids_nissan:
            continue
        unique_ids_nissan.add(i)
        total_data = get_scrapper(i, query)
        if total_data is None:
            total_data = get_scrapper(i, query)
        if total_data == 'All API key visited for today':
            return 'All API key visited for today'
        
        # Connecting to MYSQL database
        conn = db.connect(host="video-scrapping-db.cnmkmpcubdot.us-east-2.rds.amazonaws.com",
          user="asmi",
          password="asmipass123", database='METADATA')
        cur = conn.cursor()
        mySql_insert_query = """INSERT INTO nissan_car(object_name, timestamp, video_ID, link, title, description, channel_id, publishedAt,
                        thumbnailUrl, channelTitle, tags, categoryId, viewCount, likeCount, dislikeCount, 
                        favoriteCount, commentCount, uploadStatus, privacyStatus, license, embeddable, publicStatsviewable) 
                        VALUES (%s, %s, %s, %s, %s, %s, %s, %s, %s, %s,%s, %s, %s, %s ,%s, %s, %s, %s,%s, %s, %s, %s) """

        meta_datas = (query, t, total_data[0], link, total_data[1], total_data[2], total_data[3],
                     total_data[4], total_data[5], total_data[6], total_data[7], total_data[8], total_data[9],
                    total_data[10], total_data[11], total_data[12], total_data[13], total_data[14], total_data[15],
                    total_data[16], total_data[17], total_data[18])
        cur.execute(mySql_insert_query, meta_datas)
        cur.close()
        conn.commit()
        conn.close()
        
        global df_nissan
        df_nissan = df_nissan.append({'object_name':query, 'timestamp':t, 'video_ID': total_data[0], 'link':link,'title':total_data[1], 
                        'description':total_data[2], 'channel_id':total_data[3], 'publishedAt':total_data[4], 
                        'thumbnailUrl':total_data[5], 'channelTitle':total_data[6], 'tags':total_data[7], 
                        'categoryId':total_data[8], 'viewCount':total_data[9], 'likeCount':total_data[10],
                        'dislikeCount':total_data[11], 'favoriteCount':total_data[12], 'commentCount':total_data[13], 
                        'uploadStatus':total_data[14], 'privacyStatus':total_data[15], 'license':total_data[16], 
                        'embeddable':total_data[17], 'publicStatsviewable':total_data[18]}, ignore_index=True)

# %%
i_key
# Out:
# 2

# %%
timestamp = ['0:01', '0:25','2:02', '2:03','2:04', '2:04', '2:05','2:06','2:06']

final_keywords = ['nissan sentra 2020', 'white tshirt','nissan altima', 'kia forte 5', 'subaru outback', 'golf alltrack',
                 'prius prime', 'hyundai sonata', 'toyota corolla']

for t,word in zip(timestamp,final_keywords):
    a = scrapper(t,word)
    if a == 'All API key visited for today':
        print("All API key visited for today")
        break
# Out:
# nissan sentra 2020
# B1nVhMcxonA
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# -T8F9mPzQhY
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# DGn-YBbKroQ
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# kpgjbcQCeUE
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# kOE9gsknpbs
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# Nj4OREDqWfg
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# QfbFpDeeVT0
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# FSj-7EBoLiY
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# a6DcpHJ_5Fc
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# Sk5u5JkMe2M
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# xaA0Rkm7M8A
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# WACY877yVKo
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# WhSYn1nu18c
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# iIjefkC0ffc
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# cHsHNFNMuW0
# AIzaSyBvsGH7wIXILlAAS9-HvDiI-VRE3P-P_Hk
# nissan sentra 2020
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# Szos9Xijno4
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# 8fHKVIgvksU
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# MRVEwQxFYhs
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# eyjTFwDD8PA
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# qHw-8q4cIGY
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# BFq_j82AS6E
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# ygdOP0dnzY4
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# Z4Pqm8X7pTo
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# nIjJByrAqNM
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# WB2bJL-FCQA
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# PhIXsdZtTSc
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# VoaycshS-20
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# 9-RKBTAdJTM
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# owWGRmtd14g
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# ReNavsVbb9Q
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# dSAF2GrzY5k
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# AH7x7rKv0-k
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# 74oToeu8I0k
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# RzhCBE90Kb8
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# Jc56LR7nOH0
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# VZ9X4uK5vT0
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# 4gqbkTowBOI
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# honda civic
# eFU4OtFMaiE
# AIzaSyBXN-gQXmwaNXMHT_BrDG4qhG5_n5L2SCU
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-31-61be036266df> in <module>
#       7
#       8 for t,word in zip(timestamp,final_keywords):
# ----> 9     a = scrapper(t,word)
#      10     if a == 'All API key visited for today':
#      11         print("All API key visited for today")
#
# <ipython-input-29-cb6e3dcdf612> in scrapper(t, query)
#      32         conn = db.connect(host="video-scrapping-db.cnmkmpcubdot.us-east-2.rds.amazonaws.com",
#      33           user="asmi",
# ---> 34           password="asmipass123", database='METADATA')
#      35         cur = conn.cursor()
#      36         mySql_insert_query = """INSERT INTO nissan_car(object_name, timestamp, video_ID, link, title, description, channel_id, publishedAt,
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\__init__.py in connect(*args, **kwargs)
#     263     if HAVE_CEXT and not use_pure:
#     264         return CMySQLConnection(*args, **kwargs)
# --> 265     return MySQLConnection(*args, **kwargs)
#     266 Connect = connect  # pylint: disable=C0103
#     267
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\connection.py in __init__(self, *args, **kwargs)
#     102         if kwargs:
#     103             try:
# --> 104                 self.connect(**kwargs)
#     105             except:
#     106                 # Tidy-up underlying socket on failure
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\abstracts.py in connect(self, **kwargs)
#     964
#     965         self.disconnect()
# --> 966         self._open_connection()
#     967         # Server does not allow to run any other statement different from ALTER
#     968         # when user's password has been expired.
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\connection.py in _open_connection(self)
#     287         try:
#     288             self._socket.open_connection()
# --> 289             self._do_handshake()
#     290             self._do_auth(self._user, self._password,
#     291                           self._database, self._client_flags, self._charset_id,
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\connection.py in _do_handshake(self)
#     144     def _do_handshake(self):
#     145         """Get the handshake from the MySQL server"""
# --> 146         packet = self._socket.recv()
#     147         if packet[4] == 255:
#     148             raise errors.get_exception(packet)
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\mysql\connector\network.py in recv_plain(self)
#     263             packet_len = 0
#     264             while packet_len < 4:
# --> 265                 chunk = self.sock.recv(4 - packet_len)
#     266                 if not chunk:
#     267                     raise errors.InterfaceError(errno=2013)
#
# KeyboardInterrupt:

# %%
import pickle

# %%
with open('unique_ids_nissan.pickle', 'wb') as f:
    pickle.dump(unique_ids_nissan, f)
    
df_nissan.to_csv("df_nissan.csv", index=False)

# %%
print(len(unique_ids))
# Out:
# 2611

# %%
df.head()

# %%
df.shape

# %%
conn = db.connect(host="video-scrapping-db.cnmkmpcubdot.us-east-2.rds.amazonaws.com",
  user="asmi",
  password="asmipass123", database='METADATA')
cur = conn.cursor()
df = pd.read_sql('SELECT * FROM nissan_car', con=conn)

# %%
df
# Out:
# 10134  UCW-obHG7C2GSlDBilkRYTmA  2020-08-09T00:26:57Z
# 10135  UCH6-X4c-_-3kGwEKLZvOv0w  2020-12-19T20:16:47Z
# 10136  UCn_JtTOYazJgTTEUbgCzCtg  2019-06-23T10:11:44Z
# 10137  UCIf9Wr1KJzAqPrBgRt5-N6A  2021-03-03T08:00:02Z
#
#                                          thumbnailUrl  ... viewCount  \
# 0      https://i.ytimg.com/vi/Soh4Ug43MV8/default.jpg  ...       713
# 1      https://i.ytimg.com/vi/6vLYqUwvKEQ/default.jpg  ...      5741
# 2      https://i.ytimg.com/vi/B1nVhMcxonA/default.jpg  ...       618
# 3      https://i.ytimg.com/vi/-T8F9mPzQhY/default.jpg  ...         0
# 4      https://i.ytimg.com/vi/DGn-YBbKroQ/default.jpg  ...       572
# ...                                               ...  ...       ...
# 10133  https://i.ytimg.com/vi/ygdOP0dnzY4/default.jpg  ...      3525
# 10134  https://i.ytimg.com/vi/Z4Pqm8X7pTo/default.jpg  ...    502620
# 10135  https://i.ytimg.com/vi/nIjJByrAqNM/default.jpg  ...     30354
# 10136  https://i.ytimg.com/vi/WB2bJL-FCQA/default.jpg  ...      2780
# 10137  https://i.ytimg.com/vi/74oToeu8I0k/default.jpg  ...     24141
#
#       likeCount dislikeCount favoriteCount commentCount uploadStatus  \
# 0             0            0             0            0    processed
# 1            35            8             0            4    processed
# 2            16            1             0            0    processed
# 3             0            0             0            0    processed
# 4             0            0             0            0    processed
# ...         ...          ...           ...          ...          ...
# 10133       136            4             0            4    processed
# 10134     10579          281             0          404    processed
# 10135       537           50             0          181    processed
# 10136        24            1             0            2    processed
# 10137      2225           39             0          220    processed
#
#       privacyStatus  license embeddable publicStatsviewable
# 0            public  youtube          1                   0
# 1            public  youtube          1                   1
# 2            public  youtube          1                   1
# 3            public  youtube          1                   1
# 4            public  youtube          1                   0
# ...             ...      ...        ...                 ...
# 10133        public  youtube          1                   1
# 10134        public  youtube          1                   1
# 10135        public  youtube          1                   1
# 10136        public  youtube          1                   1
# 10137        public  youtube          1                   1
#
# [10138 rows x 23 columns]

# %%
df.to_csv("df_nissan_car.csv", index=False)

# %%
print(len(list(set(links))))
# Out:
# 590

# %%
print(len(new_links))
# Out:
# 636

# %%
links[-1]
# Out:
# 'https://www.youtube.com/watch?v=8H_DSErYUZk'

# %%
def get_scrapper(ids):
    categories = ['snippet', 'statistics', 'status']
    for cat in categories:
        driver.get("https://www.googleapis.com/youtube/v3/videos?part=" + cat + "&id=" + ids + "&key=AIzaSyAKkUeSAkyieoS9Ebe6HEBkjQkkae1yK4M")

        soup = BeautifulSoup(driver.page_source, 'html.parser')
        user_data = soup.find('pre').contents[0]
        user_data = user_data.replace('\n','')

        user_data = json.loads(user_data)

        items = user_data['items'][0]

        if cat == 'snippet':
            #for snippet
            local_ID = items['id']
            local_title = items['snippet']['title']
            local_description = items['snippet']['description']
            local_channel_id = items['snippet']['channelId']
            local_publishedAt = items['snippet']['publishedAt']
            local_thumbnailUrl = items['snippet']['thumbnails']['default']['url']
            local_channelTitle = items['snippet']['channelTitle']
            local_tags = items['snippet']['tags']
            local_categoryId = items['snippet']['categoryId']

        elif cat == 'statistics':
            #for statistics
            local_viewCount = items['statistics']['viewCount']
            local_likeCount = items['statistics']['likeCount']
            local_dislikeCount = items['statistics']['dislikeCount']
            local_favoriteCount = items['statistics']['favoriteCount']
            local_commentCount = items['statistics']['commentCount']

        else:
            #for status
            local_uploadStatus = items['status']['uploadStatus']
            local_privacyStatus = items['status']['privacyStatus']
            local_license = items['status']['license']
            local_embededdable = items['status']['embeddable']
            local_publicStatsViewable = items['status']['publicStatsViewable']
            
        total_data = [local_ID, local_title, local_description, local_channel_id, local_publishedAt, local_thumbnailUrl, 
                      local_channelTitle, local_tags, local_categoryId, 
                      local_viewCount, local_likeCount, local_dislikeCount, local_favoriteCount, 
                      local_commentCount, local_uploadStatus, local_privacyStatus,
                      local_license, local_embededdable, local_publicStatsViewable
                     ]
        return total_data

# %%
print(len(head))
print(len(links))
# Out:
# 595
# 595

# %%
print(len(set(head)))
# Out:
# 583

# %%
print(head[1])
# Out:
# 🔴 LIVE | Police Wolfoo Locked Up Talking Monster Police Car in Jail - Pretend Play

# %%
print(head[-20:-1])
# Out:
# ['Genetic Engineering Food | Porsche 911 Classic New Generation Car | Technology World | Ep 8', 'Colors for Children to Learn with Bus Transporter Toy Street Vehicles - Educational Videos', 'Learn Colors with WaterTank Trucks and Sports Balls for Kids #excavator, Dump Truck, Mixer Truck', 'I hid some toy cars in the farm house | Luxury car,Tempu,Sports car,Double decker bus', 'Minions vs Lightning McQueen Truck! Disney Cars and Minion Battle (Gertit ToysReview)', 'Vlad y Nikita fingen jugar heladería', 'Car Loader Trucks for kids - Cars toys videos, police chase, fire truck - Surprise eggs - Jugnu Kids', 'Learn Vechicles for Kids - Nursery Rhymes & Cars Learning Educational Video w Color for Children', 'Super Wings Special Nursery Rhymes Collection | kids songs 40 minutes| SuperWings', 'Cars 3 Transforming Fabulous Lightning McQueen Playset Transform in Raceway Track DisneyPixarCars3', 'Cars Lightning McQueen Play Doh Stop Motion video Disney cars', '20 CARS Luigi Guido Complete Diecast Collection Mattel 1:55 Disney Pixar Cars Star Wars Christmas', '자이언트 티렉스와 색깔놀이 | 자이언트 티렉스 그리고 깜짝 계란 | 어린이 교육 와 함께 컬러공 그리고 동물 | 동요와 아이 노래', 'I only collected green The airplane car transformation robot is full of toy box', 'Coleção de Super Carros de Super-Heróis, Homem Aranha, Super-Homem, Homem de Ferro - Racing Gamer', 'Box Full of Cars Toys Jackson Storm Cars 3 Disney Porsche Lamborghini Toys Cars Kids Video', '【10分映画】この車に出会ったら逃げろ･･･連続ひき逃げ車の正体は…【ザ・カー】', 'Enfer Mecanique 1977 Film Complet En Français', 'Hollywood movie ( Herbie Goes Bananas 1980 ) full movie']

# %%
df['ids'] = ids
df.head()
# Out:
#            ids
# 0  X7EXPdXek08
# 1  OUKGsb8CpF8
# 2  kRcMkt-ZxIA
# 3  OUKeADsjL7E
# 4  Secab6IPedU

# %%
# wait = WebDriverWait(driver, 10)
# v_category = "CATEGORY_NAME"
# for x in links:
#     driver.get(x)
#     v_id = x.strip('https://www.youtube.com/watch?v=')
#     v_title = wait.until(EC.presence_of_element_located(
#                (By.CSS_SELECTOR,"h1.title yt-formatted-string"))).text
#     v_description =  wait.until(EC.presence_of_element_located(
#                              (By.CSS_SELECTOR,"div#description 
#                               yt-formatted-string"))).text
#     df.loc[len(df)] = [v_id, v_title, v_description, v_category]

# %%
driver.get("about:config");

# %% [markdown]
# https://www.googleapis.com/youtube/v3/videos?part=snippet&id=XbM6PyRsJc4&key=AIzaSyAKkUeSAkyieoS9Ebe6HEBkjQkkae1yK4M

# %%
cats = ['snippet', 'statistics', 'contentDetails','fileDetails', 'player', 
        'processingDetails', 'recordingDetails','status','suggestions', 'topicDetails']
driver.get("https://www.googleapis.com/youtube/v3/videos?part=" + cats[9] + "&id=" + id + "&key=AIzaSyAKkUeSAkyieoS9Ebe6HEBkjQkkae1yK4M")

# %%
soup = BeautifulSoup(driver.page_source, 'html.parser')
user_data = soup.find('pre').contents[0]
user_data = user_data.replace('\n','')

# %%
import json
user_data = json.loads(user_data)

# %%
user_data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': '6bsk_wAqaTNzf8Z1nZLPDMRGdS8',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'odd6Xo3-CKBJfd_5aY-n6wQzYQ0',
#    'id': 'dbp91G9EA8U',
#    'status': {'uploadStatus': 'processed',
#     'privacyStatus': 'public',
#     'license': 'youtube',
#     'embeddable': True,
#     'publicStatsViewable': True,
#     'madeForKids': False}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %%
items = user_data['items'][0]
items
# Out:
# {'kind': 'youtube#video',
#  'etag': 'odd6Xo3-CKBJfd_5aY-n6wQzYQ0',
#  'id': 'dbp91G9EA8U',
#  'status': {'uploadStatus': 'processed',
#   'privacyStatus': 'public',
#   'license': 'youtube',
#   'embeddable': True,
#   'publicStatsViewable': True,
#   'madeForKids': False}}

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-189-4d247a6bca8d> in <module>()
#       1 #snippet ko lagi
#       2 ID = items['id']
# ----> 3 title = items['snippet']['title']
#       4 description = items['snippet']['description']
#       5 channel_id = items['snippet']['channelId']
#
# KeyError: 'snippet'

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-44d648212a4f> in <module>()
#       1 #statistics ko lagi
# ----> 2 viewCount = items['statistics']['viewCount']
#       3 likeCount = items['statistics']['likeCount']
#       4 dislikeCount = items['statistics']['dislikeCount']
#       5 favoriteCount = items['statistics']['favoriteCount']
#
# KeyError: 'statistics'

# %%
#snippet ko lagi
ID = items['id']
title = items['snippet']['title']
description = items['snippet']['description']
channel_id = items['snippet']['channelId']
publishedAt = items['snippet']['publishedAt']
thumbnailUrl = items['snippet']['thumbnails']['default']['url']
channelTitle = items['snippet']['channelTitle']
tags = items['snippet']['tags']
categoryId = items['snippet']['categoryId']

#statistics ko lagi
viewCount = items['statistics']['viewCount']
likeCount = items['statistics']['likeCount']
dislikeCount = items['statistics']['dislikeCount']
favoriteCount = items['statistics']['favoriteCount']
commentCount = items['statistics']['commentCount']

#status ko lagi
uploadStatus = items['status']['uploadStatus']
privacyStatus = items['status']['privacyStatus']
license = items['status']['license']
embededdable = items['status']['embeddable']
publicStatsViewable = items['status']['embeddable']

# %%
from PyDictionary import PyDictionary
from textblob import TextBlob
from textblob import Word
 
keywords_list = []
a ='ronaldo'
text_word = Word(a)
 
synonyms = set()
for synset in text_word.synsets:
    for lemma in synset.lemmas():
        synonyms.add(lemma.name())
         
if len(list(synonyms)) == 0:
    keywords_list.append(a)
else:
    keywords_list.append(a)
    keywords_list.extend(list(synonyms))

dictionary=PyDictionary()

answer = dictionary.synonym(a)
if answer is None:
    keywords_list.append(a)
else:
    keywords_list.append(a)
    keywords_list.extend(answer)
    
print(list(set(keywords_list)))
# Out:
# ronaldo has no Synonyms in the API
# ['ronaldo']

# %%
from textblob import TextBlob
from textblob import Word
 
synm = []
a = 'car'
text_word = Word(a)
 
synonyms = set()
for synset in text_word.synsets:
    for lemma in synset.lemmas():
        synonyms.add(lemma.name())
         
if len(list(synonyms)) == 0:
    synm.append(a)
else:
    synm.append(a)
    synm.extend(list(synonyms))

print(list(set(synm)))
# Out:
# ['gondola', 'machine', 'car', 'railcar', 'cable_car', 'elevator_car', 'railway_car', 'motorcar', 'railroad_car', 'automobile', 'auto']

# %%
a = [1,2,3,4]
b = [1,2,3,4]
a.extend(b)

print(a)
# Out:
# [1, 2, 3, 4, 1, 2, 3, 4]

# %%
from selenium import webdriver
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC
from selenium.common.exceptions import TimeoutException

options = webdriver.ChromeOptions()
options.add_argument("start-maximized")
options.add_experimental_option("excludeSwitches", ["enable-automation"])
options.add_experimental_option('useAutomationExtension', False)
driver = webdriver.Chrome(chrome_options=options, executable_path=r'D:\chromedriver.exe')
driver.get("https://sslproxies.org/")
driver.execute_script("return arguments[0].scrollIntoView(true);", WebDriverWait(driver, 20).until(EC.visibility_of_element_located((By.XPATH, "//table[@class='table table-striped table-bordered dataTable']//th[contains(., 'IP Address')]"))))
ips = [my_elem.get_attribute("innerHTML") for my_elem in WebDriverWait(driver, 5).until(EC.visibility_of_all_elements_located((By.XPATH, "//table[@class='table table-striped table-bordered dataTable']//tbody//tr[@role='row']/td[position() = 1]")))]
ports = [my_elem.get_attribute("innerHTML") for my_elem in WebDriverWait(driver, 5).until(EC.visibility_of_all_elements_located((By.XPATH, "//table[@class='table table-striped table-bordered dataTable']//tbody//tr[@role='row']/td[position() = 2]")))]
driver.quit()
proxies = []
for i in range(0, len(ips)):
    proxies.append(ips[i]+':'+ports[i])
print(proxies)
for i in range(0, len(proxies)):
    try:
        print("Proxy selected: {}".format(proxies[i]))
        options = webdriver.ChromeOptions()
        options.add_argument('--proxy-server={}'.format(proxies[i]))
        options.add_argument("headless") #to stop opening new chrome browser on every hit
        driver = webdriver.Chrome(options=options, executable_path=r'D:\chromedriver.exe')
        driver.get('https://www.youtube.com/results?search_query=ronaldo')
        if "Proxy Type" in WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.CSS_SELECTOR, "p.card-text"))):
            break
    except Exception:
        driver.quit()
# Out:
# ['103.28.121.58:80', '103.146.176.124:80', '95.217.22.143:8118', '103.152.5.70:8080', '51.222.173.54:3128', '198.50.152.64:23500', '124.158.88.56:54555', '159.203.124.155:3128', '157.230.103.91:43772', '110.74.199.16:63141', '180.112.1.73:8118', '112.78.170.28:8080', '179.49.57.150:6666', '216.169.73.65:34679', '119.81.189.194:80', '176.31.45.117:3128', '52.53.150.42:3128', '191.242.179.138:3128', '188.138.178.63:80', '51.158.68.68:8811']
# Proxy selected: 103.28.121.58:80
# Proxy selected: 103.146.176.124:80
# Proxy selected: 95.217.22.143:8118
# Proxy selected: 103.152.5.70:8080
# Proxy selected: 51.222.173.54:3128
# Proxy selected: 198.50.152.64:23500
# Proxy selected: 124.158.88.56:54555
# ---------------------------------------------------------------------------
# WebDriverException                        Traceback (most recent call last)
# <ipython-input-61-ee02a1eaa16d> in <module>
#      26         driver = webdriver.Chrome(options=options, executable_path=r'D:\chromedriver.exe')
# ---> 27         driver.get('https://www.youtube.com/results?search_query=ronaldo')
#      28         if "Proxy Type" in WebDriverWait(driver, 5).until(EC.visibility_of_element_located((By.CSS_SELECTOR, "p.card-text"))):
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in get(self, url)
#     332         """
# --> 333         self.execute(Command.GET, {'url': url})
#     334
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# WebDriverException: Message: unknown error: net::ERR_PROXY_CONNECTION_FAILED
#   (Session info: chrome=88.0.4324.190)
#
#
# During handling of the above exception, another exception occurred:
#
# timeout                                   Traceback (most recent call last)
# D:\Anaconda\envs\tensorflow\lib\socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-61-ee02a1eaa16d> in <module>
#      29             break
#      30     except Exception:
# ---> 31         driver.quit()
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\chrome\webdriver.py in quit(self)
#     156             pass
#     157         finally:
# --> 158             self.service.stop()
#     159
#     160     def create_options(self):
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\common\service.py in stop(self)
#     149
#     150         try:
# --> 151             self.send_remote_shutdown_command()
#     152         except TypeError:
#     153             pass
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\common\service.py in send_remote_shutdown_command(self)
#     130
#     131         for x in range(30):
# --> 132             if not self.is_connectable():
#     133                 break
#     134             else:
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\common\service.py in is_connectable(self)
#     113
#     114     def is_connectable(self):
# --> 115         return utils.is_connectable(self.port)
#     116
#     117     def send_remote_shutdown_command(self):
#
# D:\Anaconda\envs\tensorflow\lib\site-packages\selenium\webdriver\common\utils.py in is_connectable(port, host)
#     104     socket_ = None
#     105     try:
# --> 106         socket_ = socket.create_connection((host, port), 1)
#     107         result = True
#     108     except socket.error:
#
# D:\Anaconda\envs\tensorflow\lib\socket.py in create_connection(address, timeout, source_address)
#     714             if source_address:
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#     718             err = None
#
# KeyboardInterrupt:

# %%
import random

a = [1,2,3,4,5,6,7]

print(random.choice(a))
# Out:
# 7

# %%
import requests
from bs4 import BeautifulSoup
import urllib
import os
from random import choice


def get_proxy():
	proxy_url='https://www.sslproxies.org/'
	r = requests.get(proxy_url)
	soup = BeautifulSoup(r.content, 'html5lib')
	proxy = {'https': choice(list(map(lambda x:x[0]+':'+x[1], list(zip(map(lambda x:x.text, soup.findAll('td')[::8]),
		   									   map(lambda x:x.text, soup.findAll('td')[1::8]))))))}
	
	#print(proxy)
	return proxy


''' As we get a proxy lets do arequest using proxy '''
while True:
	try:
		proxy = get_proxy()
		url ="https://www.expressvpn.com/what-is-my-ip"		
		print('Using Proxy:{}'.format(proxy))
		r = requests.get(url, proxies=proxy, timeout=5)
		print(r.json())
		html = r.content
		soup = BeautifulSoup(html, 'html5lib')
		ip = soup.find('p', {'class': 'ip-address'})		
		break
	except:
		pass
print("Your ip is:",ip)
# Out:
# Using Proxy:{'https': '113.160.175.33:4145'}
# Using Proxy:{'https': '51.75.147.43:3128'}
# Using Proxy:{'https': '191.242.179.138:3128'}
# Using Proxy:{'https': '122.58.118.224:8080'}
# Using Proxy:{'https': '103.241.227.106:6666'}
# Using Proxy:{'https': '213.230.121.115:3128'}
# Using Proxy:{'https': '95.104.54.227:42119'}
# Using Proxy:{'https': '208.80.28.208:8080'}
# Using Proxy:{'https': '119.81.189.194:80'}
# Using Proxy:{'https': '198.50.163.192:3129'}
